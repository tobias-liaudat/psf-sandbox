# %% [markdown]
# # CFIS data inspection notebook

# %%
# %matplotlib notebook
import sys
sys.path.append('../../')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from mpl_toolkits.mplot3d import Axes3D
from astropy.io import fits
import random
from ShapePipe.shapepipe.pipeline import file_io

# %%
# Import the fits file
path = '/Users/tliaudat/Documents/PhD/codes/venv_p3/JB-data/other-JB-data/all_w3_star_cat/'
file_name = 'star_selection-2079613-0'
ext = '.fits'

fits_file = fits.open(path + file_name + ext)
starcat = fits_file[2].data
fits_file.info()
starcat.columns
# Out:
# Filename: /Users/tliaudat/Documents/PhD/codes/venv_p3/JB-data/other-JB-data/all_w3_star_cat/star_selection-2079613-0.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  LDAC_IMHEAD    1 BinTableHDU     12   1R x 1C   [38640A]
#   2  LDAC_OBJECTS    1 BinTableHDU    178   41R x 44C   ['1J', '1I', '1E', '1E', '1E', '1E', '1E', '1E', '1E', '1E', '1E', '1E', '1E', '1E', '1E', '1E', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1D', '1E', '1E', '1I', '1I', '1J', '1E', '1E', '1E', '1E', '2601E']
# ColDefs(
#     name = 'NUMBER'; format = '1J'; disp = 'I10'
#     name = 'EXT_NUMBER'; format = '1I'; disp = 'I3'
#     name = 'FLUX_AUTO'; format = '1E'; unit = 'count'; disp = 'G12.7'
#     name = 'FLUXERR_AUTO'; format = '1E'; unit = 'count'; disp = 'G12.7'
#     name = 'MAG_AUTO'; format = '1E'; unit = 'mag'; disp = 'F8.4'
# ...

# %%
x_world = starcat['X_WORLD']
y_world = starcat['Y_WORLD']

# %%
fig = plt.figure()
plt.scatter(x_world,y_world)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ellip = starcat['ELLIPTICITY']
elong = starcat['ELONGATION']

# %%
print(ellip)
print(elong)
# Out:
# [0.07899815 0.05761451 0.09145361 0.0487175  0.07936203 0.05907947
#  0.03357518 0.08023947 0.06560516 0.06868023 0.04864097 0.0693199
#  0.09663248 0.06672603 0.09329343 0.07662749 0.08733147 0.06990051
#  0.05348694 0.10430115 0.04974914 0.04166585 0.06756681 0.06239867
#  0.06898212 0.05272949 0.04308397 0.04906517 0.04584891 0.05178857
#  0.03725702 0.03249973 0.03069061 0.02125514 0.05534816 0.05262899
#  0.03867096 0.03408837 0.04103315 0.03653598 0.02208728]
# [1.0857742 1.0611368 1.1006593 1.0512124 1.0862033 1.0627891 1.0347416
#  1.0872395 1.0702114 1.0737451 1.0511279 1.074483  1.1069691 1.0714967
#  1.1028926 1.0829865 1.0956881 1.0751538 1.0565095 1.1164466 1.0523536
#  1.0434774 1.0724629 1.0665514 1.0740932 1.0556647 1.0450238 1.0515968
#  1.0480521 1.054617  1.0386988 1.0335914 1.0316623 1.0217167 1.058591
#  1.0555526 1.0402266 1.0352913 1.0427889 1.0379215 1.0225861]

# %%
stars = starcat['VIGNET']

# %%
fig = plt.figure()
plt.imshow(stars[8,:,:])
plt.show()

star_8 = stars[8,:,:]
star_8[star_8<1e-20] = 0
fig = plt.figure()
plt.imshow(star_8)
plt.show()
star_8
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# array([[15.630981 ,  5.6068115, 16.582    , ..., 17.970154 ,  0.       ,
#          0.       ],
#        [ 6.6334534, 11.609222 ,  0.       , ...,  0.       ,  0.       ,
#          9.874207 ],
#        [ 0.       ,  0.       ,  0.       , ...,  0.       ,  4.904907 ,
#          0.       ],
#        ...,
#        [ 0.       , 22.6698   , 28.647919 , ...,  0.       ,  0.       ,
#         14.78009  ],
#        [ 3.6898499,  0.       , 13.64743  , ...,  6.8867188,  0.       ,
#          0.       ],
#        [ 0.       ,  0.       ,  0.       , ...,  0.       ,  0.       ,
#         32.79718  ]], dtype=float32)

# %%
fig = plt.figure()
plt.imshow(stars[0,:,:])
plt.show()
stars[0,:,:]
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[ -4.3852844,  -2.3561707,  17.673218 , ...,   1.8614502,
#          16.87735  , -13.107208 ],
#        [ -9.386719 ,  32.642334 ,  11.671692 , ...,  13.858978 ,
#          -3.1250305, -31.109497 ],
#        [ -1.38797  , -21.358978 ,  12.670288 , ..., -13.143494 ,
#          15.872559 , -18.111877 ],
#        ...,
#        [-16.34967  ,   8.677673 ,   5.705078 , ...,  -5.347351 ,
#          -6.3377075,  12.671509 ],
#        [ 16.653992 ,  -5.3187256,  10.708557 , ...,  -3.3525085,
#         -19.34311  ,  26.665802 ],
#        [ 15.657745 ,  -1.3150635,  -7.287842 , ...,  13.642273 ,
#          -6.348633 , -12.339935 ]], dtype=float32)
